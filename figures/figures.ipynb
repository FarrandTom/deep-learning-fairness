# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
sns.set(style="ticks", color_codes=True, context='paper', font_scale=1.2)

matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)',
                             'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)',
                             'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)'],
    'Accuracy type': ['Overall', 'Overall', 'Overall', 'Overall', 'Overall',
                       'Female', 'Female', 'Female', 'Female', 'Female',
                       'Male', 'Male', 'Male', 'Male', 'Male'],
    'Imbalance': ['70%', '80%', '90%', '99%', '99.9%',
                  '70%', '80%', '90%', '99%', '99.9%',
                  '70%', '80%', '90%', '99%', '99.9%'],
    'Accuracy (%)': [66.76, 68.78, 71.05, 72.96, 72.23,
                     68.11, 69.47, 71.83, 73.01, 72.25,
                     63.66, 66.00, 63.94, 67.27, 33.33],
})

high_privacy_bar = sns.catplot(x="Imbalance", y="Accuracy (%)", hue="Accuracy type", col="Differential Privacy", kind="bar", data=df);
high_privacy_bar.set(ylim=(30, 92))
high_privacy_bar.savefig(f'high_privacy_bar.pdf')

# %%
df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)',
                             'Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)',
                             'Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)'],
    'Accuracy type': ['Overall', 'Overall', 'Overall', 'Overall', 'Overall',
                       'Female', 'Female', 'Female', 'Female', 'Female',
                       'Male', 'Male', 'Male', 'Male', 'Male'],
    'Imbalance': ['70%', '80%', '90%', '99%', '99.9%',
                  '70%', '80%', '90%', '99%', '99.9%',
                  '70%', '80%', '90%', '99%', '99.9%'],
    'Accuracy (%)': [84.36, 84.51, 85.61, 86.46, 86.60,
                     86.87, 86.27, 86.39, 86.61, 86.62,
                     78.61, 77.50, 78.63, 70.91, 33.33],
})

med_privacy_bar = sns.catplot(x="Imbalance", y="Accuracy (%)", hue="Accuracy type", col="Differential Privacy", kind="bar", data=df);
med_privacy_bar.set(ylim=(30, 92))
med_privacy_bar.savefig(f'med_privacy_bar.pdf')

# %%
df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)',
                             'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)',
                             'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)'],
    'Accuracy type': ['Overall', 'Overall', 'Overall', 'Overall', 'Overall',
                       'Female', 'Female', 'Female', 'Female', 'Female',
                       'Male', 'Male', 'Male', 'Male', 'Male'],
    'Imbalance': ['70%', '80%', '90%', '99%', '99.9%',
                  '70%', '80%', '90%', '99%', '99.9%',
                  '70%', '80%', '90%', '99%', '99.9%'],
    'Accuracy (%)': [85.96, 86.36, 87.51, 87.83, 87.80,
                     88.33, 87.91, 88.19, 87.97, 87.81,
                     80.54, 80.17, 81.47, 72.73, 66.67],
})

low_privacy_bar = sns.catplot(x="Imbalance", y="Accuracy (%)", hue="Accuracy type", col="Differential Privacy", kind="bar", data=df);
low_privacy_bar.set(ylim=(30, 92))
low_privacy_bar.savefig(f'low_privacy_bar.pdf')

# %%
df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['Non-DP', 'Non-DP', 'Non-DP', 'Non-DP', 'Non-DP',
                             'Non-DP', 'Non-DP', 'Non-DP', 'Non-DP', 'Non-DP',
                             'Non-DP', 'Non-DP', 'Non-DP', 'Non-DP', 'Non-DP'],
    'Accuracy type': ['Overall','Overall', 'Overall','Overall', 'Overall',
                       'Female', 'Female', 'Female', 'Female', 'Female',
                       'Male', 'Male', 'Male', 'Male', 'Male'],
    'Imbalance': ['70%', '80%', '90%', '99%', '99.9%',
                  '70%', '80%', '90%', '99%', '99.9%',
                  '70%', '80%', '90%', '99%', '99.9%'],
    'Accuracy (%)': [90.27, 90.83, 91.65, 91.13, 91.48,
                     91.36, 91.10, 92.26, 91.20, 91.48,
                     87.74, 89.75, 86.14, 83.64, 100.00],
})

non_dp_bar = sns.catplot(x="Imbalance", y="Accuracy (%)", hue="Accuracy type", col="Differential Privacy", kind="bar", data=df);
non_dp_bar.set(ylim=(60, 92))
non_dp_bar.savefig(f'non_dp_bar.pdf')

# %%
cat2 = sns.catplot(x="Imbalance", y="Accuracy (%)", col="Accuracy type", hue="Differential Privacy", kind="bar", data=df);
cat2.set(ylim=(60, 92))

# %%
fairness_df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)',
                             'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)',
                             'Non-DP', 'Non-DP', 'Non-DP'],
    'Imbalance': ['70% Female', '80% Female', '90% Female',
                  '70% Female', '80% Female', '90% Female',
                  '70% Female', '80% Female', '90% Female'],
    'Δ Demographic Parity': [0.0454, 0.0443, 0.0306,
                           0.0271, 0.0355, 0.0529,
                           0.0230, 0.0082, 0.0273],
    'Δ Equality of Opportunity': [0.0915, 0.0768, 0.0670,
                       0.0520, 0.0393, 0.0364,
                       0.0142, 0.0024, 0.0457]
})

# %%
all_demographic_parity = sns.catplot(x="Imbalance", y="Δ Demographic Parity", col="Differential Privacy", kind="bar", data=fairness_df);
all_demographic_parity.savefig(f'all_demographic_parity.pdf')

# %%
fairness_df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)'],
    'Imbalance': ['70%', '80%', '90%', '99%', '99.9%'],
    'Δ Demographic Parity': [0.0454, 0.0443, 0.0306, 0.0659, 0.0621]
})

high_privacy_demographic_parity = sns.catplot(x="Imbalance", y="Δ Demographic Parity", col="Differential Privacy", kind="bar", data=fairness_df);
high_privacy_demographic_parity.savefig(f'high_privacy_demographic_parity.pdf')

# %%
fairness_df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)'],
    'Imbalance': ['70%', '80%', '90%', '99%', '99.9%'],
    'Δ Demographic Parity': [0.0456, 0.0511, 0.0429, 0.0017, 0.2015]
})

med_privacy_demographic_parity = sns.catplot(x="Imbalance", y="Δ Demographic Parity", col="Differential Privacy", kind="bar", data=fairness_df);
med_privacy_demographic_parity.savefig(f'med_privacy_demographic_parity.pdf')

# %%
fairness_df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)'],
    'Imbalance': ['70%', '80%', '90%', '99%', '99.9%'],
    'Δ Demographic Parity': [0.0271, 0.0355, 0.0529, 0.0123, 0.1296]
})

low_privacy_demographic_parity = sns.catplot(x="Imbalance", y="Δ Demographic Parity", col="Differential Privacy", kind="bar", data=fairness_df);
low_privacy_demographic_parity.savefig(f'low_privacy_demographic_parity.pdf')

# %%
fairness_df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['Non-DP', 'Non-DP', 'Non-DP', 'Non-DP', 'Non-DP'],
    'Imbalance': ['70%', '80%', '90%', '99%', '99.9%'],
    'Δ Demographic Parity': [0.0230, 0.0082, 0.0273, 0.02, 0.1827]
})

non_dp_demographic_parity = sns.catplot(x="Imbalance", y="Δ Demographic Parity", col="Differential Privacy", kind="bar", data=fairness_df);
non_dp_demographic_parity.savefig(f'non_dp_demographic_parity.pdf')

# %%
fairness_df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)'],
    'Imbalance': ['70%', '80%', '90%', '99%', '99.9%'],
    'Δ Equality of Opportunity': [0.0915, 0.0768, 0.0670, 0.1173, 0.3259]
})

high_privacy_equality_of_opportunity = sns.catplot(x="Imbalance", y="Δ Equality of Opportunity", col="Differential Privacy", kind="bar", data=fairness_df);
high_privacy_equality_of_opportunity.savefig(f'high_privacy_equality_of_opportunity.pdf')

# %%
fairness_df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)'],
    'Imbalance': ['70%', '80%', '90%', '99%', '99.9%'],
    'Δ Equality of Opportunity': [0.0380, 0.0340, 0.0542, 0.1533, 0.3302]
})

med_privacy_equality_of_opportunity = sns.catplot(x="Imbalance", y="Δ Equality of Opportunity", col="Differential Privacy", kind="bar", data=fairness_df);
med_privacy_equality_of_opportunity.savefig(f'med_privacy_equality_of_opportunity.pdf')

# %%
fairness_df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)'],
    'Imbalance': ['70%', '80%', '90%', '99%', '99.9%'],
    'Δ Equality of Opportunity': [0.0520, 0.0393, 0.0364, 0.1593, 0.3398]
})

low_privacy_equality_of_opportunity = sns.catplot(x="Imbalance", y="Δ Equality of Opportunity", col="Differential Privacy", kind="bar", data=fairness_df);
low_privacy_equality_of_opportunity.savefig(f'low_privacy_equality_of_opportunity.pdf')

# %%
fairness_df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['Non-DP', 'Non-DP', 'Non-DP', 'Non-DP', 'Non-DP'],
    'Imbalance': ['70%', '80%', '90%', '99%', '99.9%'],
    'Δ Equality of Opportunity': [0.0142, 0.0024, 0.0457, 0.0473, 0.1027]
})

non_dp_equality_of_opportunity = sns.catplot(x="Imbalance", y="Δ Equality of Opportunity", col="Differential Privacy", kind="bar", data=fairness_df);
non_dp_equality_of_opportunity.savefig(f'non_dp_equality_of_opportunity.pdf')

# %%
delta_df = pd.DataFrame.from_dict(data={
    'Privacy Level': ['High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)',
                            'Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)', 'Med Privacy (ε=4.98)',
                            'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)',
                            'Non-DP', 'Non-DP', 'Non-DP', 'Non-DP', 'Non-DP'],
    'Imbalance': ['70%', '80%', '90%', '99%', '99.9%',
                 '70%', '80%', '90%', '99%', '99.9%',
                 '70%', '80%', '90%', '99%', '99.9%',
                 '70%', '80%', '90%', '99%', '99.9%'],
    'Δ Equality of Opportunity': [0.0915, 0.0768, 0.0670, 0.1173, 0.3259,
                                  0.0380, 0.0340, 0.0542, 0.1533, 0.3302,
                                  0.0520, 0.0393, 0.0364, 0.1593, 0.3398,
                                  0.0142, 0.0024, 0.0457, 0.0473, 0.1027],
    'Δ Demographic Parity': [0.0454, 0.0443, 0.0306, 0.0659, 0.0621,
                             0.0456, 0.0511, 0.0429, 0.0017, 0.2015,
                             0.0271, 0.0355, 0.0529, 0.0123, 0.1296,
                             0.0230, 0.0082, 0.0273, 0.02, 0.1827],
    'Δ Accuracy': [4.45, 3.47, 7.89, 5.74, 38.91, 
                   8.25, 8.77, 7.76, 15.70, 53.29,
                   7.79, 7.75, 6.72, 15.24, 21.14,
                   3.62, 1.35, 6.12, 7.56, -8.52,],
    'Δ False Negative Rate': [0.0915, 0.0786, 0.0670, 0.1173, 0.3259,
                              0.0380, 0.0340, 0.0542, 0.1533, 0.3302,
                              0.0520, 0.0393, 0.0364, 0.1593, 0.3398,
                              0.0142, 0.0024, 0.0457, 0.0473, 0.1027],
    'Δ False Positive Rate': [0.0009, 0.0091, 0.1125, 0.0061, 0.6183,
                              0.1260, 0.1413, 0.1031, 0.1610, 0.9026,
                              0.1031, 0.1157, 0.1015, 0.1466, 0.0834,
                              0.0578, 0.0248, 0.0512, 0.1423, 0.0676],
})

# %%
demographic_parity_line_plot = sns.relplot(x="Imbalance",
            y="Δ Demographic Parity",
            hue="Privacy Level",
            kind="line",
            marker='o',
            data=delta_df);
demographic_parity_line_plot.savefig(f'delta_demographic_parity_line_plot.pdf')

# %%
equality_of_opportunity_line_plot = sns.relplot(x="Imbalance",
            y="Δ Equality of Opportunity",
            hue="Privacy Level",
            kind="line",
            marker='o',
            data=delta_df);
equality_of_opportunity_line_plot.savefig(f'delta_equality_of_opportunity_line_plot.pdf')

# %%
delta_accuracy_line_plot = sns.relplot(x="Imbalance",
            y="Δ Accuracy",
            hue="Privacy Level",
            kind="line",
            marker='o',
            data=delta_df);
delta_accuracy_line_plot.savefig(f'delta_accuracy_line_plot.pdf')

# %%
delta_false_positive_line_plot = sns.relplot(x="Imbalance",
            y="Δ False Positive Rate",
            hue="Privacy Level",
            kind="line",
            marker='o',
            data=delta_df);
delta_false_positive_line_plot.savefig(f'delta_false_positive_line_plot.pdf')

# %%
delta_false_negative_line_plot = sns.relplot(x="Imbalance",
            y="Δ False Negative Rate",
            hue="Privacy Level",
            kind="line",
            marker='o',
            data=delta_df);
delta_false_negative_line_plot.savefig(f'delta_false_negative_line_plot.pdf')

# %%
sns.catplot(x="Imbalance", y="Predictive Rate Parity", col="Differential Privacy", kind="bar", data=fairness_df);

# %%
# 70% Imbalance
time_series_df = pd.read_csv('./time_series.csv')
all_time_series = sns.relplot(x='Step', y='Accuracy', hue='Differential Privacy', col='Accuracy type', data=time_series_df, kind='line')
all_time_series.savefig(f'all_time_series.pdf')

# %%
# 70% Imbalance
time_series_df = pd.read_csv('./overall_time_series.csv')
overall_time_series = sns.relplot(x='Step', y='Accuracy', hue='Differential Privacy', col='Accuracy type', data=time_series_df, kind='line')
overall_time_series.savefig(f'overall_time_series.pdf')

# %%
# 70% Imbalance
total_time_series_df = pd.read_csv('./total_time_series.csv')
total_time_series = sns.relplot(x='Step', 
                                y='Accuracy', 
                                hue='Differential Privacy', 
                                style="Group", 
                                data=total_time_series_df, 
                                kind='line')
total_time_series.savefig(f'total_time_series.pdf')

# %%
# 70% Imbalance
total_imbalance_time_series_df = pd.read_csv('./total_imbalance_time_series.csv')
total_imbalance_time_series_df = sns.relplot(x='Step', 
                                y='Accuracy', 
                                hue='Dataset Imbalance', 
                                style="Group", 
                                data=total_imbalance_time_series_df, 
                                kind='line')
total_imbalance_time_series_df.savefig(f'total_imbalance_time_series.pdf')

# %%
# 70% Imbalance
time_series_df = pd.read_csv('./female_time_series.csv')
female_time_series = sns.relplot(x='Step', y='Accuracy', hue='Differential Privacy', col='Accuracy type', data=time_series_df, kind='line')
female_time_series.savefig(f'female_time_series.pdf')

# %%
# 70% Imbalance
time_series_df = pd.read_csv('./male_time_series.csv')
male_time_series = sns.relplot(x='Step', 
                               y='Accuracy', 
                               hue='Differential Privacy', 
                               col='Accuracy type', 
                               data=time_series_df, 
                               kind='line', 
                               markers=True)
male_time_series.savefig(f'male_time_series.pdf')

# %%
clipping_results = pd.DataFrame.from_dict(data={
    'Privacy Level': ['High Privacy (ε=1.15, z=1.5)', 'High Privacy (ε=1.15, z=1.5)', 'High Privacy (ε=1.15, z=1.5)',
                       'Med Privacy (ε=4.98, z=0.7)', 'Med Privacy (ε=4.98, z=0.7)', 'Med Privacy (ε=4.98, z=0.7)',
                       'Low Privacy (ε=16.2, z=0.5)', 'Low Privacy (ε=16.2, z=0.5)', 'Low Privacy (ε=16.2, z=0.5)',
                       'High Privacy (ε=1.15, z=1.5)', 'High Privacy (ε=1.15, z=1.5)', 'High Privacy (ε=1.15, z=1.5)',
                       'Med Privacy (ε=4.98, z=0.7)', 'Med Privacy (ε=4.98, z=0.7)', 'Med Privacy (ε=4.98, z=0.7)',
                       'Low Privacy (ε=16.2, z=0.5)', 'Low Privacy (ε=16.2, z=0.5)', 'Low Privacy (ε=16.2, z=0.5)',
                       'High Privacy (ε=1.15, z=1.5)', 'High Privacy (ε=1.15, z=1.5)', 'High Privacy (ε=1.15, z=1.5)',
                       'Med Privacy (ε=4.98, z=0.7)', 'Med Privacy (ε=4.98, z=0.7)', 'Med Privacy (ε=4.98, z=0.7)',
                       'Low Privacy (ε=16.2, z=0.5)', 'Low Privacy (ε=16.2, z=0.5)', 'Low Privacy (ε=16.2, z=0.5)'],
    'Group': ['Overall', 'Female', 'Male',
                'Overall', 'Female', 'Male',
                'Overall', 'Female', 'Male',
                'Overall', 'Female', 'Male',
                'Overall', 'Female', 'Male',
                'Overall', 'Female', 'Male',
                'Overall', 'Female', 'Male',
                'Overall', 'Female', 'Male',
                'Overall', 'Female', 'Male'],
    'Clipping Bound': [1, 1, 1,
                      1, 1, 1,
                      1, 1, 1,
                      5, 5, 5,
                      5, 5, 5,
                      5, 5, 5,
                      10, 10, 10,
                      10, 10, 10,
                      10, 10, 10],
    'Demographic Parity': [0.7013, 0.7041, 0.6949,
                           0.4984, 0.4813, 0.5377,
                           0.4889, 0.4792, 0.5113,
                           0.6468, 0.6605, 0.6152,
                           0.4987, 0.4849, 0.5305,
                           0.4891, 0.4809, 0.5080,
                           0.6149, 0.6156, 0.6135,
                           0.4742, 0.4612, 0.5041,
                           0.4707, 0.4648, 0.4843],
    'Accuracy': [0.6491, 0.6620, 0.6196,
                 0.8403, 0.8656, 0.7823,
                 0.8565, 0.8792, 0.8043,
                 0.6676, 0.6811, 0.6366,
                 0.8436, 0.8687, 0.7861,
                 0.8596, 0.8833, 0.8054,
                 0.6914, 0.7112, 0.6460,
                 0.8401, 0.8646, 0.7839,
                 0.8586, 0.8787, 0.8125],
    'Equality of Opportunity': [0.8546, 0.8706, 0.8178,
                       0.8428, 0.8513, 0.8233,
                       0.8495, 0.8629, 0.8189,
                       0.8182, 0.8459, 0.7544,
                       0.8465, 0.8580, 0.8200,
                       0.8529, 0.8687, 0.8167,
                       0.8101, 0.8309, 0.7622,
                       0.8182, 0.8299, 0.7911,
                       0.8333, 0.8479, 0.8000],
    'False Positive Rate': [0.5516, 0.5416, 0.5745,
                            0.1621, 0.1205, 0.2579,
                            0.1367, 0.1049, 0.2100,
                            0.4794, 0.4797, 0.4788,
                            0.1591, 0.1210, 0.2470,
                            0.1338, 0.1026, 0.2057,
                            0.4244, 0.4055, 0.4679,
                            0.1384, 0.1016, 0.2231,
                            0.1166, 0.0912, 0.1752],
    'False Negative Rate': [0.1454, 0.1294, 0.1822,
                            0.1572, 0.1487, 0.1767,
                            0.1505, 0.1371, 0.1811,
                            0.1818, 0.1541, 0.2456,
                            0.1535, 0.1420, 0.1800,
                            0.1471, 0.1313, 0.1833,
                            0.1899, 0.1691, 0.2378,
                            0.1818, 0.1701, 0.2089,
                            0.1667, 0.1521, 0.2000]
})

# %%
clipping_accuracy_line_plot = sns.relplot(x="Clipping Bound",
            y="Accuracy",
            hue="Privacy Level",
            kind="line",
            data=clipping_results,
            style="Group",
            markers=True);
clipping_accuracy_line_plot.set(xticks=(1, 5, 10))
clipping_accuracy_line_plot.savefig(f'clipping_accuracy_line_plot.pdf')

# %%
clipping_demographic_parity_line_plot = sns.relplot(x="Clipping Bound",
            y="Demographic Parity",
            hue="Privacy Level",
            kind="line",
            data=clipping_results,
            style="Group",
            markers=True);
clipping_demographic_parity_line_plot.set(xticks=(1, 5, 10))
clipping_demographic_parity_line_plot.savefig(f'clipping_demographic_parity_line_plot.pdf')

# %%
clipping_equalised_odds_line_plot = sns.relplot(x="Clipping Bound",
            y="Equality of Opportunity",
            hue="Privacy Level",
            kind="line",
            data=clipping_results,
            style="Group",
            markers=True);
clipping_equalised_odds_line_plot.set(xticks=(1, 5, 10))
clipping_equalised_odds_line_plot.savefig(f'clipping_equalised_odds_line_plot.pdf')

# %%
clipping_false_positive_line_plot = sns.relplot(x="Clipping Bound",
            y="False Positive Rate",
            hue="Privacy Level",
            kind="line",
            data=clipping_results,
            style="Category",
            markers=True);
clipping_false_positive_line_plot.set(xticks=(1, 5, 10))
clipping_false_positive_line_plot.savefig(f'clipping_false_positive_line_plot.pdf')

# %%
clipping_false_negative_line_plot = sns.relplot(x="Clipping Bound",
            y="False Negative Rate",
            hue="Privacy Level",
            kind="line",
            data=clipping_results,
            style="Category",
            markers=True);
clipping_false_negative_line_plot.set(xticks=(1, 5, 10))
clipping_false_negative_line_plot.savefig(f'clipping_false_negative_line_plot.pdf')

# %%
demographic_parity = pd.read_csv('./demographic_parity.csv', encoding = 'utf-8')
demographic_parity_plot = sns.relplot(x="Imbalance",
            y="Demographic Parity",
            hue="Privacy Level",
            kind="line",
            data=demographic_parity,
            style="Category",
            markers=True);
demographic_parity_plot.set(xticks=(0.7, 0.8, 0.9, 0.99, 0.999))

# %%
clipping_delta_df = pd.DataFrame.from_dict(data={
    'Privacy Level': ['High Privacy (ε=1.15)', 'Med Privacy (ε=4.98)', 'Low Privacy (ε=16.2)',
                      'High Privacy (ε=1.15)', 'Med Privacy (ε=4.98)', 'Low Privacy (ε=16.2)',
                      'High Privacy (ε=1.15)', 'Med Privacy (ε=4.98)', 'Low Privacy (ε=16.2)'],
    'Clipping Bound': [1, 1, 1,
                  5, 5, 5,
                  10, 10, 10],
    'Δ Equality of Opportunity': [0.0529, 0.0279, 0.0440,
                                  0.0915, 0.0380, 0.0520, 
                                  0.0687, 0.0388, 0.0479],
    'Δ Demographic Parity': [0.0092, 0.0563, 0.0321,
                             0.0454, 0.0456, 0.0271,
                             0.0020, 0.0429, 0.0195],
    'Δ Accuracy': [4.24, 8.33, 7.49,
                   4.45, 8.25, 7.79, 
                   6.53, 8.06, 6.62],
    'Δ False Negative Rate': [0.0529, 0.0279, 0.0440,
                              0.0915, 0.0380, 0.0520, 
                              0.0687, 0.0388, 0.0479],
    'Δ False Positive Rate': [0.0329, 0.1374, 0.1051,
                              0.0009, 0.1260, 0.1031,
                              0.0624, 0.1215, 0.0840],
})

# %%
delta_clipping_accuracy_line_plot = sns.relplot(x="Clipping Bound",
            y="Δ Accuracy",
            hue="Privacy Level",
            kind="line",
            data=clipping_delta_df,
            marker='o');
delta_clipping_accuracy_line_plot.set(xticks=(1, 5, 10))
delta_clipping_accuracy_line_plot.savefig(f'delta_clipping_accuracy_line_plot.pdf')

# %%
delta_clipping_equalised_odds_line_plot = sns.relplot(x="Clipping Bound",
            y="Δ Equality of Opportunity",
            hue="Privacy Level",
            kind="line",
            data=clipping_delta_df,
            marker='o');
delta_clipping_equalised_odds_line_plot.set(xticks=(1, 5, 10))
delta_clipping_equalised_odds_line_plot.savefig(f'delta_clipping_equalised_odds_line_plot.pdf')

# %%
delta_clipping_demographic_parity_line_plot = sns.relplot(x="Clipping Bound",
            y="Δ Demographic Parity",
            hue="Privacy Level",
            kind="line",
            data=clipping_delta_df,
            marker='o');
delta_clipping_demographic_parity_line_plot.set(xticks=(1, 5, 10))
delta_clipping_demographic_parity_line_plot.savefig(f'delta_clipping_demographic_parity_line_plot.pdf')

# %%
delta_clipping_false_negative_line_plot = sns.relplot(x="Clipping Bound",
            y="Δ False Negative Rate",
            hue="Privacy Level",
            kind="line",
            data=clipping_delta_df,
            marker='o');
delta_clipping_false_negative_line_plot.set(xticks=(1, 5, 10))
delta_clipping_false_negative_line_plot.savefig(f'delta_clipping_false_negative_line_plot.pdf')

# %%
delta_clipping_false_positive_line_plot = sns.relplot(x="Clipping Bound",
            y="Δ False Positive Rate",
            hue="Privacy Level",
            kind="line",
            data=clipping_delta_df,
            marker='o');
delta_clipping_false_positive_line_plot.set(xticks=(1, 5, 10))
delta_clipping_false_positive_line_plot.savefig(f'delta_clipping_false_positive_line_plot.pdf')
