# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set(style="ticks", color_codes=True)

# %%
df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)',
                             'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)',
                             'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)',
                             'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)',
                             'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)',
                             'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)',
                             'Non-DP', 'Non-DP', 'Non-DP',
                             'Non-DP', 'Non-DP', 'Non-DP',
                             'Non-DP', 'Non-DP', 'Non-DP'],
    'Accuracy type': ['Overall','Overall', 'Overall',
                       'Female', 'Female', 'Female',
                       'Male', 'Male', 'Male',
                       'Overall','Overall', 'Overall',
                       'Female', 'Female', 'Female',
                       'Male', 'Male', 'Male',
                       'Overall','Overall', 'Overall',
                       'Female', 'Female', 'Female',
                       'Male', 'Male', 'Male'],
    'Imbalance': ['70% Female', '80% Female', '90% Female',
                  '70% Female', '80% Female', '90% Female',
                  '70% Female', '80% Female', '90% Female',
                  '70% Female', '80% Female', '90% Female',
                  '70% Female', '80% Female', '90% Female',
                  '70% Female', '80% Female', '90% Female',
                  '70% Female', '80% Female', '90% Female',
                  '70% Female', '80% Female', '90% Female',
                  '70% Female', '80% Female', '90% Female'],
    'Accuracy (%)': [66.76, 68.78, 71.05,
                     68.11, 69.47, 71.83,
                     63.66, 66.00, 63.94,
                     85.96, 86.36, 87.51,
                     88.33, 87.91, 88.19,
                     80.54, 80.17, 81.47,
                     90.27, 90.83, 91.72,
                     91.36, 91.10, 92.20,
                     87.74, 89.75, 87.31],
})

cat = sns.catplot(x="Imbalance", y="Accuracy (%)", hue="Accuracy type", col="Differential Privacy", kind="bar", data=df);
cat.set(ylim=(60, 92))
cat.savefig(f'all_accuracy_bars.pdf')

# %%
df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)',
                             'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)',
                             'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)'],
    'Accuracy type': ['Overall','Overall', 'Overall',
                       'Female', 'Female', 'Female',
                       'Male', 'Male', 'Male'],
    'Imbalance': ['70% Female', '80% Female', '90% Female',
                  '70% Female', '80% Female', '90% Female',
                  '70% Female', '80% Female', '90% Female'],
    'Accuracy (%)': [66.76, 68.78, 71.05,
                     68.11, 69.47, 71.83,
                     63.66, 66.00, 63.94],
})

high_privacy_bar = sns.catplot(x="Imbalance", y="Accuracy (%)", hue="Accuracy type", col="Differential Privacy", kind="bar", data=df);
high_privacy_bar.set(ylim=(60, 92))
high_privacy_bar.savefig(f'high_privacy_bar.pdf')

# %%
df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)',
                             'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)',
                             'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)'],
    'Accuracy type': ['Overall','Overall', 'Overall',
                       'Female', 'Female', 'Female',
                       'Male', 'Male', 'Male'],
    'Imbalance': ['70% Female', '80% Female', '90% Female',
                  '70% Female', '80% Female', '90% Female',
                  '70% Female', '80% Female', '90% Female'],
    'Accuracy (%)': [85.96, 86.36, 87.51,
                     88.33, 87.91, 88.19,
                     80.54, 80.17, 81.47],
})

low_privacy_bar = sns.catplot(x="Imbalance", y="Accuracy (%)", hue="Accuracy type", col="Differential Privacy", kind="bar", data=df);
low_privacy_bar.set(ylim=(60, 92))
low_privacy_bar.savefig(f'low_privacy_bar.pdf')

# %%
df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['Non-DP', 'Non-DP', 'Non-DP',
                             'Non-DP', 'Non-DP', 'Non-DP',
                             'Non-DP', 'Non-DP', 'Non-DP'],
    'Accuracy type': ['Overall','Overall', 'Overall',
                       'Female', 'Female', 'Female',
                       'Male', 'Male', 'Male'],
    'Imbalance': ['70% Female', '80% Female', '90% Female',
                  '70% Female', '80% Female', '90% Female',
                  '70% Female', '80% Female', '90% Female'],
    'Accuracy (%)': [90.27, 90.83, 91.65,
                     91.36, 91.10, 92.26,
                     87.74, 89.75, 86.14],
})

non_dp_bar = sns.catplot(x="Imbalance", y="Accuracy (%)", hue="Accuracy type", col="Differential Privacy", kind="bar", data=df);
non_dp_bar.set(ylim=(60, 92))
non_dp_bar.savefig(f'non_dp_bar.pdf')

# %%
cat2 = sns.catplot(x="Imbalance", y="Accuracy (%)", col="Accuracy type", hue="Differential Privacy", kind="bar", data=df);
cat2.set(ylim=(60, 92))

# %%
cat3 = sns.relplot(x="Imbalance", y="Accuracy (%)", col="Accuracy type", hue="Differential Privacy", kind="line", data=df);
cat3.set(ylim=(60, 92))

# %%
fairness_df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)',
                             'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)',
                             'Non-DP', 'Non-DP', 'Non-DP'],
    'Imbalance': ['70% Female', '80% Female', '90% Female',
                  '70% Female', '80% Female', '90% Female',
                  '70% Female', '80% Female', '90% Female'],
    'Δ Demographic Parity': [0.0454, 0.0443, 0.0306,
                           0.0271, 0.0355, 0.0529,
                           0.0230, 0.0082, 0.0273],
    'Δ Equality of Opportunity': [0.0915, 0.0768, 0.0670,
                       0.0520, 0.0393, 0.0364,
                       0.0142, 0.0024, 0.0457],
    'Δ Predictive Rate Parity': [0.0256, 0.0208, 0.0420,
                               0.0966, 0.1034, 0.0688,
                               0.0538, 0.0241, 0.0375],
    'Δ Accuracy Parity': [0.0445, 0.0347, 0.0789,
                        0.0779, 0.0775, 0.0672,
                        0.0362, 0.0135, 0.0489],
    'Δ False Negative Rate Parity': [0.0915, 0.0768, 0.0670,
                                   0.0520, 0.0393, 0.0364,
                                   0.0142, 0.0024, 0.0457],
    'Δ False Positive Rate Parity': [0.0009, 0.0091, 0.1125,
                                   0.1031, 0.1157, 0.1015,
                                   0.0578, 0.0248, 0.0512],
    'Δ Negative Predictive Value Parity': [0.0916, 0.0661, 0.1420,
                                         0.0595, 0.0502, 0.0674,
                                         0.0188, 0.0033, 0.0624],
    'Δ Specificity Parity': [0.0009, 0.0091, 0.1125,
                           0.1031, 0.1157, 0.1015,
                           0.0578, 0.0248, 0.0512],
    'Δ Matthews correlation coefficient comparison': [0.1034, 0.0771, 0.1818,
                                                    0.1556, 0.1543, 0.1370,
                                                    0.0723, 0.0273, 0.0984]
})

# %%
all_demographic_parity = sns.catplot(x="Imbalance", y="Δ Demographic Parity", col="Differential Privacy", kind="bar", data=fairness_df);
all_demographic_parity.savefig(f'all_demographic_parity.pdf')

# %%
fairness_df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)'],
    'Imbalance': ['70% Female', '80% Female', '90% Female'],
    'Δ Demographic Parity': [0.0454, 0.0443, 0.0306]
})

high_privacy_demographic_parity = sns.catplot(x="Imbalance", y="Δ Demographic Parity", col="Differential Privacy", kind="bar", data=fairness_df);
high_privacy_demographic_parity.savefig(f'high_privacy_demographic_parity.pdf')

# %%
fairness_df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)'],
    'Imbalance': ['70% Female', '80% Female', '90% Female'],
    'Δ Demographic Parity': [0.0271, 0.0355, 0.0529]
})

low_privacy_demographic_parity = sns.catplot(x="Imbalance", y="Δ Demographic Parity", col="Differential Privacy", kind="bar", data=fairness_df);
low_privacy_demographic_parity.savefig(f'low_privacy_demographic_parity.pdf')

# %%
fairness_df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['Non-DP', 'Non-DP', 'Non-DP'],
    'Imbalance': ['70% Female', '80% Female', '90% Female'],
    'Δ Demographic Parity': [0.0230, 0.0082, 0.0010]
})

non_dp_demographic_parity = sns.catplot(x="Imbalance", y="Δ Demographic Parity", col="Differential Privacy", kind="bar", data=fairness_df);
non_dp_demographic_parity.savefig(f'non_dp_demographic_parity.pdf')

# %%
all_equality_of_opportunity = sns.catplot(x="Imbalance", y="Δ Equality of Opportunity", col="Differential Privacy", kind="bar", data=fairness_df);
all_equality_of_opportunity.savefig(f'all_equality_of_opportunity.pdf')

# %%
fairness_df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['High Privacy (ε=1.15)', 'High Privacy (ε=1.15)', 'High Privacy (ε=1.15)'],
    'Imbalance': ['70% Female', '80% Female', '90% Female'],
    'Δ Equality of Opportunity': [0.0915, 0.0768, 0.0670]
})

high_privacy_equality_of_opportunity = sns.catplot(x="Imbalance", y="Δ Equality of Opportunity", col="Differential Privacy", kind="bar", data=fairness_df);
high_privacy_equality_of_opportunity.savefig(f'high_privacy_equality_of_opportunity.pdf')

# %%
fairness_df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)', 'Low Privacy (ε=16.2)'],
    'Imbalance': ['70% Female', '80% Female', '90% Female'],
    'Δ Equality of Opportunity': [0.0520, 0.0393, 0.0364]
})

low_privacy_equality_of_opportunity = sns.catplot(x="Imbalance", y="Δ Equality of Opportunity", col="Differential Privacy", kind="bar", data=fairness_df);
low_privacy_equality_of_opportunity.savefig(f'low_privacy_equality_of_opportunity.pdf')

# %%
fairness_df = pd.DataFrame.from_dict(data={
    'Differential Privacy': ['Non-DP', 'Non-DP', 'Non-DP'],
    'Imbalance': ['70% Female', '80% Female', '90% Female'],
    'Δ Equality of Opportunity': [0.0142, 0.0024, 0.0457]
})

non_dp_equality_of_opportunity = sns.catplot(x="Imbalance", y="Δ Equality of Opportunity", col="Differential Privacy", kind="bar", data=fairness_df);
non_dp_equality_of_opportunity.savefig(f'non_dp_equality_of_opportunity.pdf')

# %%
sns.catplot(x="Imbalance", y="Matthews correlation coefficient comparison", col="Differential Privacy", kind="bar", data=fairness_df);

# %%
sns.catplot(x="Imbalance", y="Predictive Rate Parity", col="Differential Privacy", kind="bar", data=fairness_df);

# %%
# 70% Imbalance
time_series_df = pd.read_csv('./time_series.csv')
all_time_series = sns.relplot(x='Step', y='Accuracy', hue='Differential Privacy', col='Accuracy type', data=time_series_df, kind='line')
all_time_series.savefig(f'all_time_series.pdf')

# %%
# 70% Imbalance
time_series_df = pd.read_csv('./overall_time_series.csv')
overall_time_series = sns.relplot(x='Step', y='Accuracy', hue='Differential Privacy', col='Accuracy type', data=time_series_df, kind='line')
overall_time_series.savefig(f'overall_time_series.pdf')

# %%
# 70% Imbalance
time_series_df = pd.read_csv('./female_time_series.csv')
female_time_series = sns.relplot(x='Step', y='Accuracy', hue='Differential Privacy', col='Accuracy type', data=time_series_df, kind='line')
female_time_series.savefig(f'female_time_series.pdf')

# %%
# 70% Imbalance
time_series_df = pd.read_csv('./male_time_series.csv')
male_time_series = sns.relplot(x='Step', y='Accuracy', hue='Differential Privacy', col='Accuracy type', data=time_series_df, kind='line')
male_time_series.savefig(f'male_time_series.pdf')
